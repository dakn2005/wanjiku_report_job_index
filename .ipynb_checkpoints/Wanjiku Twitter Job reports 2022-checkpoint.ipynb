# %% [markdown]
# ## Job Reports 2022
# ### Table of Contents
# 1. Text cleaning and extraction
# 1. Wordcloud
# 1. Sentiment Analysis

# %%
import pandas as pd
import os, json
import pandas as pd
import numpy as np
import glob
import re
import sys

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
np.set_printoptions(threshold=sys.maxsize)

# %%
companies = {
    '1': 'Safaricom', 
    '2': 'EABL', 
    '3': 'UN, United Nations', 
    '4': 'KRA', 
    '5': 'KenGen', 
    '6': 'KPC, Kenya Pipeline Company', 
    '7': 'Coca cola', 
    '8':'Deloitte', 
    '9': 'Unilever', 
    '10': 'Kplc, Kenya Power', 
    '11': 'Google', 
    '12': 'KPA, Kenya Ports Authority',
    '13': 'KCB, Kenya Commercial Bank', 
    '14': 'Microsoft', 
    '15': 'Bidco', 
    '16': 'RMS, Royal Media Services', 
    '17': 'KEMRI, Kenya Medical Research Institute',
    '18': 'Amref'
}

# %% [markdown]
# Export tweets (json format)

# %%
# f = open('./dayta/1-json.json')
arr = []
path_to_json = './dayta/'
json_pattern = os.path.join(path_to_json, '*.json')
file_list = glob.glob(json_pattern)

# print(file_list)

for file in file_list:
    with open(file) as f:
        temp = json.load(f)
        for line in temp['data']:
            arr.append(line)



df = pd.DataFrame(data=arr)
# save to csv
df.to_csv('./out/collated.csv')

df = df[['text', 'created_at']]

# df.head(100)

# %% [markdown]
# #### Text Cleaning and Extraction

# %% [markdown]
# ##### Pre-processing

# %%
txt_lower = df['text'].str.lower()
txt_l_cln = txt_lower.str.replace("\@wanjikureports", "") #replace wanjiku mentions
txt_l_cln2 = txt_l_cln.str.replace("(\n*\d\.)", '') #replace ordered listings e.g. 1., 2. etc
narr = txt_l_cln2.to_numpy()

# %% [markdown]
# **Pseudocode**
#
# Each listitem in list
# - Remove all stop words
# - Split all words/numbers
# - Check whether word in company list, if in list add to output var -> use eigenvalues, check for closeness of word
# - check each # with company list key, add value to output list

# %%
from stop_words import get_stop_words
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = list(get_stop_words('en'))  # About 900 stopwords
nltk_words = list(stopwords.words('english'))  # About 150 stopwords
stop_words.extend(nltk_words)

# %%
from difflib import SequenceMatcher
import jellyfish

def similar(a, b):
    return jellyfish.jaro_distance(a, b)  # prob threshhold set at 0.75
    # return SequenceMatcher(None, a, b).ratio()


def returnFromNumeric(numstr):
    if 1 <= int(numstr) <= 18:
        splt = companies[numstr].split(',')
        return splt[0]

# https://stackoverflow.com/questions/51217909/removing-all-emojis-from-text


def replaceEmoji(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U0001F1F2-\U0001F1F4"  # Macau flag
                               u"\U0001F1E6-\U0001F1FF"  # flags
                               u"\U0001F600-\U0001F64F"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U0001F1F2"
                               u"\U0001F1F4"
                               u"\U0001F620"
                               u"\u200d"
                               u"\u2640-\u2642"
                               "]+", flags=re.UNICODE)

    return emoji_pattern.sub(r'', text)


def returnFromStr(thestr):
    output = None

    for val in companies.values():
        splt = val.split(',')

        selected = splt[0]
        prob = similar(thestr, splt[0].strip().lower())
        prob2 = 0
        
        if len(splt) > 1:
            prob2 = similar(thestr, splt[1].strip().lower())
            
        prob = prob2 if prob2 > prob else prob
        
#         apparently, as per test below kenya_ports is closer to kplc than kpa!
#         print(similar('kenya_ports', 'Kenya Ports authority'.lower()))
#         print(similar('kenya_ports', 'Kenya power'.lower()))
#         Capture manually
        if selected.lower() == 'kplc' and 'port' in thestr:
            prob = 0

        if prob >= .75:
            if output is not None:
                prev_prob = similar(thestr, output.lower())
                if prob > prev_prob:
                    output = selected
            else:
                output = selected
                    
#     if output is not None:
#         print('<b>Tumetoa: {}</b>'.format(output))

    return output

# %%
similar('kenya_ports', 'Kenya Ports Authority'.lower())

# thevar = 'KPA, Kenya pipes'.split(',')
# print(thevar[0])
# if (len(thevar) > 1):
#     print(thevar[1])
# Out:
# 0.7950937950937952

# %% [markdown]
# **Correct for numbers errors, when numbers are separated by a comma!**

# %%
output_arr = []
test = narr[:5]

for i, sentence in enumerate(narr):
    internal_arr = []
    if i not in [1096]: #908, 1073, 1096
        final_tokens = []
#         tokens = [word for word in word_tokenize(sentence) if word.lower() == 'un' and not word in stopwords.words()] 
        tokens = word_tokenize(sentence)
        for tkn in tokens:
            if tkn.lower() == 'un':
                final_tokens.append(tkn)
            else:
                if tkn not in stopwords.words():
                    final_tokens.append(tkn)
            
            
#         print('\n----------------------------\n{} {} {}\n---------------------------'.format(i, sentence, tokens))
        
        for token in final_tokens:
            if token.isnumeric():
                internal_arr.append(returnFromNumeric(token))
            else:
                ret_str = returnFromStr(token)
#                 print(ret_str)
                internal_arr.append(ret_str)
        
        print(i, sentence, final_tokens, internal_arr, '\n')
                
    
    output_arr.append(list(set(internal_arr)))
    
    
#flatten output_arr
output_arr = [element for sublist in output_arr for element in sublist]
# Out:
# 0  @kenya_ports of course. i've been dying to get even just an internship here. ['@', 'kenya_ports', 'course', '.', "'ve", 'dying', 'get', 'even', 'internship', '.'] [None, 'KPA', None, None, None, None, None, None, None, None]
#
# 1  6 ['6'] ['KPC']
#
# 2  7 ['7'] ['Coca cola']
#
# 3  amref ['amref'] ['Amref']
#
# 4  where are the hustler companies? ['hustler', 'companies', '?'] [None, None, None]
#
# 5  8,11 or 1🙏amen. ['8,11', '1🙏amen', '.'] [None, None, None]
#
# 6  kpa ['kpa'] ['KPA']
#
# 7  not a sucker for employment, but i won't mind working at; google microsoft deloitte unilever ['sucker', 'employment', ',', "n't", 'mind', 'working', ';', 'google', 'microsoft', 'deloitte', 'unilever'] [None, None, None, None, None, None, None, 'Google', 'Microsoft', 'Deloitte', 'Unilever']
#
# 8  mimi nipewe kazi kwa serekali hapo ndio ntaiba vizuri ['mimi', 'nipewe', 'kazi', 'kwa', 'serekali', 'hapo', 'ndio', 'ntaiba', 'vizuri'] [None, None, None, 'KRA', None, None, None, None, None]
#
# 9  my own [] []
#
# 10  13 @kcbgroup . been my all time bank. i hope one day it will come to pass. inshallah ['13', '@', 'kcbgroup', '.', 'time', 'bank', '.', 'hope', 'day', 'pass', '.', 'inshallah'] ['KCB', None, 'KCB', None, None, None, None, None, None, None, None, None]
#
# 11  @amref_worldwide would be my 1st choice…fingers crossed,prayers on. ['@', 'amref_worldwide', 'would', '1st', 'choice…fingers', 'crossed', ',', 'prayers', '.'] [None, 'Amref', None, None, None, None, None, None, None]
#
# 12  google ['google'] ['Google']
#
# 13  united nations 🇺🇳 ['united', 'nations', '🇺🇳'] ['UN', None, None]
#
# 14  google ['google'] ['Google']
#
# 15  united nations ['united', 'nations'] ['UN', None]
#
# 16  @kenya ports authority ['@', 'kenya', 'ports', 'authority'] [None, 'Kplc', None, None]
#
# 17  11 ['11'] ['Google']
#
# 18  1 ['1'] ['Safaricom']
#
# 19  eabl and kpa ['eabl', 'kpa'] ['EABL', 'KPA']
#
# 20  3 or 6 ['3', '6'] ['UN', 'KPC']
#
# 21  9 ['9'] ['Unilever']
#
# 22  @safaricomplc ... god knows how much i wanna work here... fingers crossed ☺️ ['@', 'safaricomplc', '...', 'god', 'knows', 'much', 'wan', 'work', '...', 'fingers', 'crossed', '☺️'] [None, 'Safaricom', None, None, None, None, None, None, None, None, None, None]
#
# 23  @kenyapipeline ['@', 'kenyapipeline'] [None, 'KPC']
#
# 24  3 ['3'] ['UN']
#
# 25  eabl ['eabl'] ['EABL']
#
# 26  safaricom ['safaricom'] ['Safaricom']
#
# 27  2 ['2'] ['EABL']
#
# 28  kenya commercial bank has been my dream employer ['kenya', 'commercial', 'bank', 'dream', 'employer'] ['Kplc', None, None, None, None]
#
# 29  @bidcogroup always ['@', 'bidcogroup', 'always'] [None, 'Bidco', None]
#
# 30  cocacola company i need internship on automotive engineering course finished my diploma this year december ['cocacola', 'company', 'need', 'internship', 'automotive', 'engineering', 'course', 'finished', 'diploma', 'year', 'december'] ['Coca cola', None, None, None, None, None, None, None, None, None, None]
#
# 31  4 ['4'] ['KRA']
#
# 32  google ['google'] ['Google']
#
# 33  @microsoft i would like to have an opportunity to work at your company. i am a great admirer of ms. thank you. ['@', 'microsoft', 'would', 'like', 'opportunity', 'work', 'company', '.', 'great', 'admirer', 'ms.', 'thank', '.'] [None, 'Microsoft', None, None, None, None, None, None, None, 'Amref', None, None, None]
#
# 34 @victorkombenzai  😂😂🙌 ['@', 'victorkombenzai', '😂😂🙌'] [None, None, None]
#
# 35  kra ['kra'] ['KRA']
#
# 36  @kengen.i wish one day, i will be lucky. ['@', 'kengen.i', 'wish', 'day', ',', 'lucky', '.'] [None, 'KenGen', None, None, None, None, None]
#
# 37  @royalmediaservices ['@', 'royalmediaservices'] [None, 'RMS']
#
# 38  number 3 under wfp ['number', '3', 'wfp'] [None, 'UN', None]
#
# 39  2|4|7|11|14 ['2|4|7|11|14'] [None]
#
# 40  @kenyapower_care as a customer service executive. i would love that opportunity. ['@', 'kenyapower_care', 'customer', 'service', 'executive', '.', 'would', 'love', 'opportunity', '.'] [None, 'Kplc', None, None, None, None, None, None, None, None]
#
# 41  wish next year i can get somewhere to be employed...its really frustrating ['wish', 'next', 'year', 'get', 'somewhere', 'employed', '...', 'really', 'frustrating'] [None, None, None, None, None, None, None, 'EABL', None]
#
# 42  @eabl_plc ['@', 'eabl_plc'] [None, 'EABL']
#
# 43  @un darling ['@', 'un', 'darling'] [None, 'UN', None]
#
# 44  kcb does not qualify on this list. ['kcb', 'qualify', 'list', '.'] ['KCB', None, None, None]
#
# 45  no 18 ['18'] ['Amref']
#
# 46  safaricom the best option ['safaricom', 'best', 'option'] ['Safaricom', None, None]
#
# 47  amref ['amref'] ['Amref']
#
# 48  1 ['1'] ['Safaricom']
#
# 49  kra,,😋 ['kra', ',', ',😋'] ['KRA', None, None]
#
# 50  kengen as a geologist ['kengen', 'geologist'] ['KenGen', None]
#
# 51  the first row of 1 7 13 ['first', 'row', '1', '7', '13'] [None, None, 'Safaricom', 'Coca cola', 'KCB']
#
# 52  google
# microsoft
# royal media services
# or safaricom ['google', 'microsoft', 'royal', 'media', 'services', 'safaricom'] ['Google', 'Microsoft', 'RMS', None, None, 'Safaricom']
#
# 53  united nations ['united', 'nations'] ['UN', None]
#
# 54  the transformational agenda with @kengenkenya is on another level. ['transformational', 'agenda', '@', 'kengenkenya', 'another', 'level', '.'] [None, None, None, 'KenGen', None, 'Unilever', None]
#
# 55  un ['un'] ['UN']
#
# 56  3 ['3'] ['UN']
#
# 57  delloite espencially on investigation side ['delloite', 'espencially', 'investigation', 'side'] ['Deloitte', None, None, None]
#
# 58  google ['google'] ['Google']
#
# 59  @wanjiku_reports @deloittekenya ['@', 'wanjiku_reports', '@', 'deloittekenya'] [None, None, None, 'Deloitte']
#
# 60  4 ['4'] ['KRA']
#
# 61   deloitte ['deloitte'] ['Deloitte']
#
# 62  eabl
# bat
# coca cola
# safaricom
# kra
# un ['eabl', 'bat', 'coca', 'cola', 'safaricom', 'kra', 'un'] ['EABL', None, 'Coca cola', None, 'Safaricom', 'KRA', 'UN']
#
# 63  @safaricomplc any day any time ['@', 'safaricomplc', 'day', 'time'] [None, 'Safaricom', None, None]
#
# 64  kra ['kra'] ['KRA']
#
# 65  i would feel very grateful and advantaged working for @google as a junior it security analyst for more experiences napenda services zao  #employment ['would', 'feel', 'grateful', 'advantaged', 'working', '@', 'google', 'junior', 'security', 'analyst', 'experiences', 'napenda', 'services', 'zao', '#', 'employment'] [None, None, None, None, None, None, 'Google', 'UN', None, None, None, None, None, None, None, None]
#
# 66  any would be okay working in the it dept, but it's only @un that would give me the fulfillment, serving humanity, being out there on the field...life changing experiences. ['would', 'okay', 'working', 'dept', ',', "'s", '@', 'un', 'would', 'give', 'fulfillment', ',', 'serving', 'humanity', ',', 'field', '...', 'life', 'changing', 'experiences', '.'] [None, None, None, None, None, None, None, 'UN', None, None, None, None, None, 'UN', None, None, None, None, None, None, None]
#
# 67  sol gen ['sol', 'gen'] [None, None]
#
# 68  google ['google'] ['Google']
#
# 69 @lemmygunga  unataka kupipe mayengs na wamama wa ploti ['@', 'lemmygunga', 'unataka', 'kupipe', 'mayengs', 'wamama', 'wa', 'ploti'] [None, None, 'UN', None, None, None, None, None]
#
# 70  @microsoft ['@', 'microsoft'] [None, 'Microsoft']
#
# 71  @moiuniversityke the foundation of knowledge. 😎 ['@', 'moiuniversityke', 'foundation', 'knowledge', '.', '😎'] [None, None, None, None, None, None]
#
# 72  today's sure winning ticket is ready my whatsapp link👉👉👉https://t.co/mnjmdz4ixx https://t.co/dj6vcaanhi ['today', "'s", 'sure', 'winning', 'ticket', 'ready', 'whatsapp', 'link👉👉👉https', ':', '//t.co/mnjmdz4ixx', 'https', ':', '//t.co/dj6vcaanhi'] [None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 73  @un  here i come. ['@', 'un', '.'] [None, 'UN', None]
#
# 74  amref ['amref'] ['Amref']
#
# 75  14 @microsoft ['14', '@', 'microsoft'] ['Microsoft', None, 'Microsoft']
#
# 76  3 ['3'] ['UN']
#
# 77  kengen/kenya pipeline/kenya port🕯️🕯️ ['kengen/kenya', 'pipeline/kenya', 'port🕯️🕯️'] ['KenGen', None, None]
#
# 78 @_o_g_k  my thoughts too... g.o.k is one of the best employers. ['@', '_o_g_k', 'thoughts', '...', 'g.o.k', 'best', 'employers', '.'] [None, None, None, None, None, None, None, None]
#
# 79  @unitednationsjo ['@', 'unitednationsjo'] [None, 'UN']
#
# 80  google ['google'] ['Google']
#
# 81  kpa ['kpa'] ['KPA']
#
# 82 @jamalgaddafi  worked with them for the last 5 years. good employer yes. but the office politics ain't healthy at all. ['@', 'jamalgaddafi', 'worked', 'last', '5', 'years', '.', 'good', 'employer', 'yes', '.', 'office', 'politics', "n't", 'healthy', '.'] [None, None, None, None, 'KenGen', None, None, 'Google', None, None, None, None, None, None, None, None]
#
# 83  @kcbgroup as a dsr 😊 ['@', 'kcbgroup', 'dsr', '😊'] [None, 'KCB', None, None]
# 84  id like to work with @kenya_ports an opportunity will be a turning point of my life. ['id', 'like', 'work', '@', 'kenya_ports', 'opportunity', 'turning', 'point', 'life', '.'] ['Bidco', None, None, None, 'KPA', None, 'UN', None, None, None]
#
# 85  amref dktr githinji gitahi my role model ['amref', 'dktr', 'githinji', 'gitahi', 'role', 'model'] ['Amref', None, None, None, 'Google', None]
#
# 86  @conrad_jlm amref, microsoft, united nations ['@', 'conrad_jlm', 'amref', ',', 'microsoft', ',', 'united', 'nations'] [None, None, 'Amref', None, 'Microsoft', None, 'UN', None]
#
# 87 @tha_crusaider  @bidcogroup i wish you luck ['@', 'tha_crusaider', '@', 'bidcogroup', 'wish', 'luck'] [None, None, None, 'Bidco', None, None]
#
# 88  united nations ['united', 'nations'] ['UN', None]
#
# 89  7,11,14 ['7,11,14'] [None]
#
# 90  safaricom ['safaricom'] ['Safaricom']
#
# 91  internship tu @kengenkenya ['internship', '@', 'kengenkenya'] [None, None, 'KenGen']
#
# 92  united nations ['united', 'nations'] ['UN', None]
#
# 93  3 ['3'] ['UN']
#
# 94  what is kcb doing there ['kcb'] ['KCB']
#
# 95  @kracorporate @kracare ['@', 'kracorporate', '@', 'kracare'] [None, 'KRA', None, 'KRA']
#
# 96  6 nataka mafuta . ['6', 'nataka', 'mafuta', '.'] ['KPC', None, None, None]
#
# 97  l'oreal ["l'oreal"] [None]
#
# 98  un
# safaricom
# google
# microsoft 🙏🙏 ['un', 'safaricom', 'google', 'microsoft', '🙏🙏'] ['UN', 'Safaricom', 'Google', 'Microsoft', None]
#
# 99  cocacola ['cocacola'] ['Coca cola']
#
# 100 @dagitari_  @kcbgroup umekuwa member ['@', 'dagitari_', '@', 'kcbgroup', 'umekuwa', 'member'] [None, None, None, 'KCB', None, None]
#
# 101 @cacxy @joenyayo  @amref_kenya that's maturity. 👏🏾 ['@', 'cacxy', '@', 'joenyayo', '@', 'amref_kenya', "'s", 'maturity', '.', '👏🏾'] [None, None, None, None, None, 'Amref', None, None, None, None]
#
# 102 @engmagondu1 @joenyayo  @amref_kenya thank you bw. engeneer, always ready to be corrected. to @joenyayo i stand to be correcred and every day is a learning day. sikua na ubaya btw. ['@', 'engmagondu1', '@', 'joenyayo', '@', 'amref_kenya', 'thank', 'bw', '.', 'engeneer', ',', 'always', 'ready', 'corrected', '.', '@', 'joenyayo', 'stand', 'correcred', 'every', 'day', 'learning', 'day', '.', 'sikua', 'ubaya', 'btw', '.'] [None, None, None, None, None, 'Amref', None, None, None, 'KenGen', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 103  start your own brand ['start', 'brand'] [None, None]
#
# 104 @governorkiongos  @kengenkenya electrical &amp; electronics eng. ['@', 'governorkiongos', '@', 'kengenkenya', 'electrical', '&', 'amp', ';', 'electronics', 'eng', '.'] [None, None, None, 'KenGen', None, None, None, None, None, 'KenGen', None]
#
# 105  3 ['3'] ['UN']
#
# 106  royal media services, @citizentvkenya ['royal', 'media', 'services', ',', '@', 'citizentvkenya'] ['RMS', None, None, None, None, None]
#
# 107  eabl ['eabl'] ['EABL']
#
# 108  kra ['kra'] ['KRA']
#
# 109  if @aphrc/@africacdc, i hope one day it will be a reality. ['@', 'aphrc/', '@', 'africacdc', ',', 'hope', 'day', 'reality', '.'] [None, None, None, None, None, None, None, None, None]
#
# 110  @kengenkenya ['@', 'kengenkenya'] [None, 'KenGen']
#
# 111  wale eabl tunasimama wapi ['wale', 'eabl', 'tunasimama', 'wapi'] [None, 'EABL', None, None]
#
# 112  @un ['@', 'un'] [None, 'UN']
#
# 113  un ['un'] ['UN']
#
# 114 @itsdennohbruh @anti_saiyan  uta tarmack hadi u tii ['@', 'itsdennohbruh', '@', 'anti_saiyan', 'uta', 'tarmack', 'hadi', 'tii'] [None, None, None, None, None, None, None, None]
#
# 115  all the above  [] []
#
# 116 @governorkiongos @anti_saiyan  probably😂🤝🏼 ['@', 'governorkiongos', '@', 'anti_saiyan', 'probably😂🤝🏼'] [None, None, None, None, None]
#
# 117  no. 12 ['.', '12'] [None, 'KPA']
#
# 118  @safaricomplc  @safaricom_care  nataka kazi ['@', 'safaricomplc', '@', 'safaricom_care', 'nataka', 'kazi'] [None, 'Safaricom', None, 'Safaricom', None, None]
#
# 119 @njoro_githiri  @kengenkenya course gani bro ['@', 'njoro_githiri', '@', 'kengenkenya', 'course', 'gani', 'bro'] [None, None, None, 'KenGen', None, None, None]
#
# 120  @kemri_kenya ['@', 'kemri_kenya'] [None, 'KEMRI']
#
# 121  un, google or microsoft ['un', ',', 'google', 'microsoft'] ['UN', None, 'Google', 'Microsoft']
#
# 122 @anti_saiyan  kwani ume fanya. industrial chem ['@', 'anti_saiyan', 'kwani', 'ume', 'fanya', '.', 'industrial', 'chem'] [None, None, None, None, None, None, None, None]
#
# 123  kra ['kra'] ['KRA']
#
# 124  google ['google'] ['Google']
#
# 125 @ogendooyugi  people are making serious money out here while a teacher takes home 30k ndiyo afanye nayo nini hii nairobi? ['@', 'ogendooyugi', 'people', 'making', 'serious', 'money', 'teacher', 'takes', 'home', '30k', 'ndiyo', 'afanye', 'nayo', 'nini', 'hii', 'nairobi', '?'] [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 126  @safaricom_care has been my dream company ['@', 'safaricom_care', 'dream', 'company'] [None, 'Safaricom', None, None]
#
# 127  @eabl_plc ['@', 'eabl_plc'] [None, 'EABL']
#
# 128  kpa ['kpa'] ['KPA']
#
# 129  why??start ups? ['?', '?', 'start', 'ups', '?'] [None, None, None, None, None]
#
# 130  @kcbgroup @unilever and @cocacolaafrica ['@', 'kcbgroup', '@', 'unilever', '@', 'cocacolaafrica'] [None, 'KCB', None, 'Unilever', None, 'Coca cola']
#
# 131 @mwderek  you have a good point there ['@', 'mwderek', 'good', 'point'] [None, None, 'Google', None]
#
# 132  5 ['5'] ['KenGen']
#
# 133  @kengenkenya or @kenyapower ['@', 'kengenkenya', '@', 'kenyapower'] [None, 'KenGen', None, 'Kplc']
#
# 134  @kengenkenya ['@', 'kengenkenya'] [None, 'KenGen']
#
# 135  i would love the opportunity to work with the @un ['would', 'love', 'opportunity', 'work', '@', 'un'] [None, None, None, None, None, 'UN']
#
# 136  deloitte, kra and unilever ['deloitte', ',', 'kra', 'unilever'] ['Deloitte', None, 'KRA', 'Unilever']
#
# 137  not there but definitely @binance ['definitely', '@', 'binance'] [None, None, None]
#
# 138  safaricom kengen google microsoft in that order 😌 ['safaricom', 'kengen', 'google', 'microsoft', 'order', '😌'] ['Safaricom', 'KenGen', 'Google', 'Microsoft', None, None]
#
# 139  18, inshallah ['18', ',', 'inshallah'] ['Amref', None, None]
#
# 140 @itsbillyricky @mstephano_  idhi kod agencies matiyo gi un kata agencies mag tich kuonde go. ['@', 'itsbillyricky', '@', 'mstephano_', 'idhi', 'kod', 'agencies', 'matiyo', 'gi', 'un', 'agencies', 'mag', 'tich', 'kuonde', 'go', '.'] [None, None, None, None, None, None, None, None, None, 'UN', None, None, None, 'UN', 'Google', None]
#
# 141  man, i interned at @kengenkenya engineering dept si i had hopes after campus....wooii!!! i simped and simped. lordt!! this life, no balance. [',', 'interned', '@', 'kengenkenya', 'engineering', 'dept', 'hopes', 'campus', '....', 'wooii', '!', '!', '!', 'simped', 'simped', '.', 'lordt', '!', '!', 'life', ',', 'balance', '.'] [None, None, None, 'KenGen', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 142  microsoft ['microsoft'] ['Microsoft']
#
# 143  microsoft ['microsoft'] ['Microsoft']
#
# 144  kengen ['kengen'] ['KenGen']
#
# 145 @ogendooyugi  we don't pay bills with those funny quotes. it's either paying your bills or it's not. ['@', 'ogendooyugi', "n't", 'pay', 'bills', 'funny', 'quotes', '.', "'s", 'either', 'paying', 'bills', "'s", '.'] [None, None, None, None, None, 'UN', None, None, None, None, None, None, None, None]
#
# 146  @kracare ['@', 'kracare'] [None, 'KRA']
#
# 147  3 bana or any ngo ['3', 'bana', 'ngo'] ['UN', None, None]
#
# 148 @mwderek  but i thought teaching is a calling,what happened? ['@', 'mwderek', 'thought', 'teaching', 'calling', ',', 'happened', '?'] [None, None, None, None, None, None, None, None]
#
# 149  11, 14, or 1 ['11', ',', '14', ',', '1'] ['Google', None, 'Microsoft', None, 'Safaricom']
#
# 150  you chose the best ['chose', 'best'] [None, None]
#
# 151  @kengenkenya ['@', 'kengenkenya'] [None, 'KenGen']
#
# 152  why would you put bidco here..a company which pay 30k for a management role ['would', 'put', 'bidco', '..', 'company', 'pay', '30k', 'management', 'role'] [None, None, 'Bidco', None, None, None, None, None, 'Google']
#
# 153  kenya pipeline company ['kenya', 'pipeline', 'company'] ['Kplc', None, None]
#
# 154  11 ['11'] ['Google']
#
# 155  @kcbgroup ['@', 'kcbgroup'] [None, 'KCB']
# 156  14 ['14'] ['Microsoft']
#
# 157  @safaricom_care .dream. ['@', 'safaricom_care', '.dream', '.'] [None, 'Safaricom', None, None]
#
# 158  5 ['5'] ['KenGen']
#
# 159 @ogendooyugi  jakano yawa. walimu kwanza wameambiwa walipe 6k ndio waendelee kufunzwa new skills by force. mimi i'm in my last year of teaching. naenda profession ingine ['@', 'ogendooyugi', 'jakano', 'yawa', '.', 'walimu', 'kwanza', 'wameambiwa', 'walipe', '6k', 'ndio', 'waendelee', 'kufunzwa', 'new', 'skills', 'force', '.', 'mimi', "'m", 'last', 'year', 'teaching', '.', 'naenda', 'profession', 'ingine'] [None, None, None, None, None, None, None, None, None, None, None, None, 'UN', None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 160  3,5,6 ['3,5,6'] [None]
#
# 161  @amref_kenya it is.. ['@', 'amref_kenya', '..'] [None, 'Amref', None]
#
# 162  @deloittekenya dreams are valid ['@', 'deloittekenya', 'dreams', 'valid'] [None, 'Deloitte', None, None]
#
# 163  working with @safaricomplc @safaricom_care  must be a dream come true. their working environment is well designed. their employees are smart. i wish i work with them some day ['working', '@', 'safaricomplc', '@', 'safaricom_care', 'must', 'dream', 'true', '.', 'working', 'environment', 'well', 'designed', '.', 'employees', 'smart', '.', 'wish', 'work', 'day'] [None, None, 'Safaricom', None, 'Safaricom', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 164  nene feeds ['nene', 'feeds'] [None, None]
#
# 165  13 @kcbgroup 🤞🏿 ['13', '@', 'kcbgroup', '🤞🏿'] ['KCB', None, 'KCB', None]
#
# 166  hey @kengenkenya 👋... ['hey', '@', 'kengenkenya', '👋', '...'] [None, None, 'KenGen', None, None]
#
# 167  is g.o.k a joke to you? ['g.o.k', 'joke', '?'] [None, None, None]
#
# 168 @w_dennis001  @eabl_plc wacha hizo bana 😂😂😂 ['@', 'w_dennis001', '@', 'eabl_plc', 'wacha', 'hizo', 'bana', '😂😂😂'] [None, None, None, 'EABL', None, None, None, None]
#
# 169  misati realtors ['misati', 'realtors'] [None, None]
#
# 170  it should be not just working, working in which capacity? ['working', ',', 'working', 'capacity', '?'] [None, None, None, None, None]
#
# 171 @johnrashford8  @eabl_plc wanaogopa unaeza kunywa stock ['@', 'johnrashford8', '@', 'eabl_plc', 'wanaogopa', 'unaeza', 'kunywa', 'stock'] [None, None, None, 'EABL', None, 'UN', 'UN', None]
#
# 172  @eabl_plc definitely ['@', 'eabl_plc', 'definitely'] [None, 'EABL', None]
#
# 173  @kcbgroup ['@', 'kcbgroup'] [None, 'KCB']
#
# 174  no. 1, safaricom of course ['.', '1', ',', 'safaricom', 'course'] [None, 'Safaricom', None, 'Safaricom', None]
#
# 175 @odhisjakagwa  kuome 💉 ['@', 'odhisjakagwa', 'kuome', '💉'] [None, None, None, None]
#
# 176  12 ['12'] ['KPA']
#
# 177  any of the above, having worked in top 4 of the top 1 [',', 'worked', 'top', '4', 'top', '1'] [None, None, None, 'KRA', None, 'Safaricom']
#
# 178  @un ['@', 'un'] [None, 'UN']
#
# 179  google mechanical engineer ['google', 'mechanical', 'engineer'] ['Google', None, 'KenGen']
#
# 180  12 ['12'] ['KPA']
#
# 181  microsoft ['microsoft'] ['Microsoft']
#
# 182  @safaricomplc  wakuu si mfanye ile kitu nitume cv tafazali. ['@', 'safaricomplc', 'wakuu', 'mfanye', 'kitu', 'nitume', 'cv', 'tafazali', '.'] [None, 'Safaricom', None, None, None, None, None, None, None]
#
# 183  @kcbgroup ['@', 'kcbgroup'] [None, 'KCB']
#
# 184  @keyamour 1 ['@', 'keyamour', '1'] [None, 'Kplc', 'Safaricom']
#
# 185  2&amp;7 ['2', '&', 'amp', ';', '7'] ['EABL', None, None, None, 'Coca cola']
#
# 186  coca cola ['coca', 'cola'] ['Coca cola', None]
#
# 187  un ['un'] ['UN']
#
# 188  google ['google'] ['Google']
#
# 189  @un ['@', 'un'] [None, 'UN']
#
# 190 @mwderek  ni kama utakuwa tu mwalimu peke yako ['@', 'mwderek', 'kama', 'utakuwa', 'mwalimu', 'peke', 'yako'] [None, None, None, None, None, None, None]
#
# 191  united nations ['united', 'nations'] ['UN', None]
#
# 192 @yatsinedwin hi, thank you for your interest to work with us. go to https://t.co/uwjx8izgmj to register and apply for job vacancies. ^js ['@', 'yatsinedwin', 'hi', ',', 'thank', 'interest', 'work', 'us', '.', 'go', 'https', ':', '//t.co/uwjx8izgmj', 'register', 'apply', 'job', 'vacancies', '.', '^js'] [None, None, None, None, None, None, None, None, None, 'Google', None, None, None, None, None, None, None, None, None]
#
# 193  above all, avoid amaco insurance.
# thank me later.
# happy xmas. [',', 'avoid', 'amaco', 'insurance', '.', 'thank', 'later', '.', 'happy', 'xmas', '.'] [None, None, None, None, None, None, None, None, None, None, None]
#
# 194 @kenyapower_care @dannk_9 6 and 5 ['@', 'kenyapower_care', '@', 'dannk_9', '6', '5'] [None, 'Kplc', None, None, 'KPC', 'KenGen']
#
# 195  eabl ['eabl'] ['EABL']
#
# 196  @kenyapipeline save a citizen.. i'm a qualified project manager fit for you in your organization and work areas .. i wouldn't mind starting being on probation.. this would be a perfect 2022 for me 🙏🙏🙏 ['@', 'kenyapipeline', 'save', 'citizen', '..', "'m", 'qualified', 'project', 'manager', 'fit', 'organization', 'work', 'areas', '..', 'would', "n't", 'mind', 'starting', 'probation', '..', 'would', 'perfect', '2022', '🙏🙏🙏'] [None, 'KPC', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 197 @pnalele @mstephano_  idhi through agencies ama itiyo kod un? ['@', 'pnalele', '@', 'mstephano_', 'idhi', 'agencies', 'itiyo', 'kod', 'un', '?'] [None, None, None, None, None, None, None, None, 'UN', None]
#
# 198  @virusijr 7 ['@', 'virusijr', '7'] [None, None, 'Coca cola']
#
# 199  bidco @bidcogroup ['bidco', '@', 'bidcogroup'] ['Bidco', None, 'Bidco']
#
# 200  @microsoft, @google and @un  any day 😊 ['@', 'microsoft', ',', '@', 'google', '@', 'un', 'day', '😊'] [None, 'Microsoft', None, None, 'Google', None, 'UN', None, None]
#
# 201  @kentrade_g2b nipeeni job ['@', 'kentrade_g2b', 'nipeeni', 'job'] [None, 'KRA', None, None]
#
# 202 @daktari254  that’s how you kept failing exams 🤓 ['@', 'daktari254', '’', 'kept', 'failing', 'exams', '🤓'] [None, None, None, None, None, None, None]
#
# 203  @kracorporate ['@', 'kracorporate'] [None, 'KRA']
#
# 204  none since i work for my company @netlitdigital . i already own some shares but my goal next year is to buy atleast 100shares in each of the companies on that list before dec 202 if i achieve that, they will be working for me. thank you @amerix for misleading me to shareholding ['none', 'since', 'work', 'company', '@', 'netlitdigital', '.', 'already', 'shares', 'goal', 'next', 'year', 'buy', 'atleast', '100shares', 'companies', 'list', 'dec', '202', 'achieve', ',', 'working', '.', 'thank', '@', 'amerix', 'misleading', 'shareholding'] [None, None, None, None, None, None, None, None, None, 'Google', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 205  @un all the time ['@', 'un', 'time'] [None, 'UN', None]
#
# 206  @un, specifically @undp ['@', 'un', ',', 'specifically', '@', 'undp'] [None, 'UN', None, None, None, 'UN']
#
# 207  17 the reality in science ['17', 'reality', 'science'] ['KEMRI', None, None]
#
# 208  with my skills i can do good at 18,12,5 and 3 ['skills', 'good', '18,12,5', '3'] [None, 'Google', None, 'UN']
#
# 209  @kengenkenya
# @eabl_plc
# @kenyapipeline
# unilever ['@', 'kengenkenya', '@', 'eabl_plc', '@', 'kenyapipeline', 'unilever'] [None, 'KenGen', None, 'EABL', None, 'KPC', 'Unilever']
#
# 210  @unilever 🥺 ['@', 'unilever', '🥺'] [None, 'Unilever', None]
#
# 211  2 and 10 ['2', '10'] ['EABL', 'Kplc']
#
# 212  15 ['15'] ['Bidco']
#
# 213 @snapped254  @bidcogroup 44 hours week? ['@', 'snapped254', '@', 'bidcogroup', '44', 'hours', 'week', '?'] [None, None, None, 'Bidco', None, None, None, None]
#
# 214  18 with gg. ['18', 'gg', '.'] ['Amref', 'Google', None]
#
# 215  @kcbgroup 😊 ['@', 'kcbgroup', '😊'] [None, 'KCB', None]
#
# 216  @amref_worldwide ['@', 'amref_worldwide'] [None, 'Amref']
#
# 217  definitely 16
#
# their digital platform has been stepping up of late ['definitely', '16', 'digital', 'platform', 'stepping', 'late'] [None, 'RMS', None, None, None, None]
#
# 218  @un my dream company, i hope one day my application will go through 🙏 ['@', 'un', 'dream', 'company', ',', 'hope', 'day', 'application', 'go', '🙏'] [None, 'UN', None, None, None, None, None, None, 'Google', None]
#
# 219  @google how are you 😊😊 hope i'm welcome 😊 ['@', 'google', '😊😊', 'hope', "'m", 'welcome', '😊'] [None, 'Google', None, None, None, None, None]
#
# 220 @ralphassault  kengen ['@', 'ralphassault', 'kengen'] [None, None, 'KenGen']
# 221  @amref_kenya made several applications without success but my dream is still on @daktari1 ['@', 'amref_kenya', 'made', 'several', 'applications', 'without', 'success', 'dream', 'still', '@', 'daktari1'] [None, 'Amref', None, None, None, None, None, None, None, None, None]
#
# 222  hey @safaricomplc and @cocacolaafrica  i'm a commercial model and i would love to work with you ['hey', '@', 'safaricomplc', '@', 'cocacolaafrica', "'m", 'commercial', 'model', 'would', 'love', 'work'] [None, None, 'Safaricom', None, 'Coca cola', None, None, None, None, None, None]
#
# 223  @dhlpaket ['@', 'dhlpaket'] [None, None]
#
# 224  united nations ['united', 'nations'] ['UN', None]
#
# 225  14 or 11😢🕯 ['14', '11😢🕯'] ['Microsoft', None]
#
# 226  i am already working for the best company ever. ['already', 'working', 'best', 'company', 'ever', '.'] [None, None, None, None, None, None]
#
# 227  coca cola ['coca', 'cola'] ['Coca cola', None]
#
# 228  kra ['kra'] ['KRA']
#
# 229  @kengenkenya  ama @kenyapower ['@', 'kengenkenya', '@', 'kenyapower'] [None, 'KenGen', None, 'Kplc']
#
# 230  united nation; world tourism organization ['united', 'nation', ';', 'world', 'tourism', 'organization'] ['UN', None, None, None, None, None]
#
# 231 @clements_malit  register through the link or you can dm ['@', 'clements_malit', 'register', 'link', 'dm'] [None, None, None, None, None]
#
# 232  google ['google'] ['Google']
#
# 233  i die for @bidcogroup ['@', 'bidcogroup'] [None, 'Bidco']
#
# 234  @safaricomplc  @safaricom_care  ndo niache kuteseka na fuliza.😴😴😴 https://t.co/oppeicbfkv ['@', 'safaricomplc', '@', 'safaricom_care', 'ndo', 'niache', 'kuteseka', 'fuliza.😴😴😴', 'https', ':', '//t.co/oppeicbfkv'] [None, 'Safaricom', None, 'Safaricom', None, None, None, None, None, None, None]
#
# 235  all [] []
#
# 236  2 ['2'] ['EABL']
#
# 237 @kenyapower_care @dannk_9 guy is open for a job ['@', 'kenyapower_care', '@', 'dannk_9', 'guy', 'open', 'job'] [None, 'Kplc', None, None, None, None, None]
#
# 238  kenya pipeline company ['kenya', 'pipeline', 'company'] ['Kplc', None, None]
#
# 239  @microsoft ['@', 'microsoft'] [None, 'Microsoft']
#
# 240 @jamadar_1  can you take me through this? ['@', 'jamadar_1', '?'] [None, None, None]
#
# 241  if @safaricomplc had a digital marketing role, then my skills in consumer psychology would be indispensable. ['@', 'safaricomplc', 'digital', 'marketing', 'role', ',', 'skills', 'consumer', 'psychology', 'would', 'indispensable', '.'] [None, 'Safaricom', None, None, 'Google', None, None, None, None, None, None, None]
#
# 242  safaricom or unilever. ['safaricom', 'unilever', '.'] ['Safaricom', 'Unilever', None]
#
# 243  @google ['@', 'google'] [None, 'Google']
#
# 244  be self employed and enjoy the benefits ['self', 'employed', 'enjoy', 'benefits'] [None, None, None, None]
#
# 245  @kcbgroup no one understands asset finance marketing (digital)better. i look forward to. ['@', 'kcbgroup', 'understands', 'asset', 'finance', 'marketing', '(', 'digital', ')', 'better', '.', 'look', 'forward', '.'] [None, 'KCB', None, None, None, None, None, None, None, None, None, None, None, None]
#
# 246  employment is for lame people ['employment', 'lame', 'people'] [None, 'Amref', None]
#
# 247  google ['google'] ['Google']
#
# 248  @un @safaricomplc @unilever would be great. with over 8 years experience in strategic planning, performance contracting and a seasoned intellectual property professional, l believe i would be an asset worth hiring  and retaining! ['@', 'un', '@', 'safaricomplc', '@', 'unilever', 'would', 'great', '.', '8', 'years', 'experience', 'strategic', 'planning', ',', 'performance', 'contracting', 'seasoned', 'intellectual', 'property', 'professional', ',', 'believe', 'would', 'asset', 'worth', 'hiring', 'retaining', '!'] [None, 'UN', None, 'Safaricom', None, 'Unilever', None, None, None, 'Deloitte', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 249  any would do tbh, with the current state of affairs most kenyans would be grateful getting a job from any of these nice companies ['would', 'tbh', ',', 'current', 'state', 'affairs', 'kenyans', 'would', 'grateful', 'getting', 'job', 'nice', 'companies'] [None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 250  google ['google'] ['Google']
#
# 251   @deloittekenya @deloitte i am an auditor ['@', 'deloittekenya', '@', 'deloitte', 'auditor'] [None, 'Deloitte', None, 'Deloitte', None]
#
# 252  @safaricomplc ['@', 'safaricomplc'] [None, 'Safaricom']
#
# 253  @kracare i would make your tax collection seamless by solving 98% of problems i see. ['@', 'kracare', 'would', 'make', 'tax', 'collection', 'seamless', 'solving', '98', '%', 'problems', 'see', '.'] [None, 'KRA', None, None, None, None, None, None, None, None, None, None, None]
#
# 254  sioni @dhlmex my dream company ['sioni', '@', 'dhlmex', 'dream', 'company'] [None, None, None, None, None]
#
# 255  @un i am ready. when do i start as a procurement officer? 😂😂 ['@', 'un', 'ready', '.', 'start', 'procurement', 'officer', '?', '😂😂'] [None, 'UN', None, None, None, None, None, None, None]
#
# 256  google ['google'] ['Google']
#
# 257  un any day, then amref, ['un', 'day', ',', 'amref', ','] ['UN', None, None, 'Amref', None]
#
# 258  1, 2, 3, 7, 8, 9, 13-18 ['1', ',', '2', ',', '3', ',', '7', ',', '8', ',', '9', ',', '13-18'] ['Safaricom', None, 'EABL', None, 'UN', None, 'Coca cola', None, 'Deloitte', None, 'Unilever', None, None]
#
# 259  google  ['google'] ['Google']
#
# 260 @charlieyahyoh  huku ni wapi? https://t.co/t9wvomroe2 ['@', 'charlieyahyoh', 'huku', 'wapi', '?', 'https', ':', '//t.co/t9wvomroe2'] [None, None, None, None, None, None, None, None]
#
# 261  https://t.co/5jnmc8wzl9 ['https', ':', '//t.co/5jnmc8wzl9'] [None, None, None]
#
# 262  kemri ['kemri'] ['KEMRI']
#
# 263 @loudahcfc @dannk_9 man's simping big time 😂 ['@', 'loudahcfc', '@', 'dannk_9', "'s", 'simping', 'big', 'time', '😂'] [None, None, None, None, None, None, None, None, None]
#
# 264  @kengenkenya ['@', 'kengenkenya'] [None, 'KenGen']
#
# 265  build my own.."palse" ['build', '..', "''", 'palse', "''"] [None, None, None, None, None]
#
# 266  5 ['5'] ['KenGen']
#
# 267  google ['google'] ['Google']
#
# 268  un ['un'] ['UN']
#
# 269  @britamea ['@', 'britamea'] [None, None]
#
# 270  kpc ['kpc'] ['KPC']
#
# 271  united nations ['united', 'nations'] ['UN', None]
#
# 272  my own [] []
#
# 273  3,12,18 ['3,12,18'] [None]
#
# 274  google ['google'] ['Google']
#
# 275  1,3 or 11 ['1,3', '11'] [None, 'Google']
#
# 276  kra @kracorporate ['kra', '@', 'kracorporate'] ['KRA', None, 'KRA']
#
# 277 @wagalla_jnr  unataka hiyo crazy per diem running some pointless errands😂😂 ['@', 'wagalla_jnr', 'unataka', 'hiyo', 'crazy', 'diem', 'running', 'pointless', 'errands😂😂'] [None, None, 'UN', None, None, None, 'UN', None, None]
#
# 278  kra ['kra'] ['KRA']
#
# 279  @kracare  the best company ['@', 'kracare', 'best', 'company'] [None, 'KRA', None, None]
#
# 280  @un  @amref_worldwide @amref_kenya ['@', 'un', '@', 'amref_worldwide', '@', 'amref_kenya'] [None, 'UN', None, 'Amref', None, 'Amref']
#
# 281  4 ['4'] ['KRA']
#
# 282  k r a ['r'] ['RMS']
#
# 283  aache matusi na kiburi ya pesa ya wizi ['aache', 'matusi', 'kiburi', 'pesa', 'wizi'] [None, None, None, None, None]
#
# 284  kenya ports authority ['kenya', 'ports', 'authority'] ['Kplc', None, None]
#
# 285  @kengenkenya ni weke wapi cv ['@', 'kengenkenya', 'weke', 'wapi', 'cv'] [None, 'KenGen', None, None, None]
#
# 286  ukijua mtu alivote 4,5,6,10,12,16, 17 then you have known a millionaire already. in these companies sio mshahara hukufikisha uendako but kunyanyasa raia na hefty tokens za reliability and convenience. all you need is work on your communications skills, dress the part and charge ['ukijua', 'mtu', 'alivote', '4,5,6,10,12,16', ',', '17', 'known', 'millionaire', 'already', '.', 'companies', 'sio', 'mshahara', 'hukufikisha', 'uendako', 'kunyanyasa', 'raia', 'hefty', 'tokens', 'reliability', 'convenience', '.', 'need', 'work', 'communications', 'skills', ',', 'dress', 'part', 'charge'] [None, None, None, None, None, 'KEMRI', None, None, None, None, None, None, None, None, 'UN', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 287  @spotify my dream job would be to work with this company ['@', 'spotify', 'dream', 'job', 'would', 'work', 'company'] [None, None, None, None, None, None, None]
#
# 288  https://t.co/ciwyk1qtu0 ['https', ':', '//t.co/ciwyk1qtu0'] [None, None, None]
#
# 289  coco cola ['coco', 'cola'] ['Coca cola', None]
#
# 290  @isuzukenya 👈🏼 ['@', 'isuzukenya', '👈🏼'] [None, None, None]
#
# 291 @neshiebensoul  did you get called for the internship? ['@', 'neshiebensoul', 'get', 'called', 'internship', '?'] [None, None, None, None, None, None]
# 292  @amref_worldwide  always been a dream ['@', 'amref_worldwide', 'always', 'dream'] [None, 'Amref', None, None]
#
# 293  2&amp;8 ['2', '&', 'amp', ';', '8'] ['EABL', None, None, None, 'Deloitte']
#
# 294  has to be safaricom..to be their events manager because am an event manager ['safaricom', '..', 'events', 'manager', 'event', 'manager'] ['Safaricom', None, None, None, None, None]
#
# 295  @google  can we?😭 ['@', 'google', '?', '😭'] [None, 'Google', None, None]
#
# 296  5 ['5'] ['KenGen']
#
# 297  @kenyapipeline
# @kracorporate
# @kracare
#
# may god here this humble prayer ['@', 'kenyapipeline', '@', 'kracorporate', '@', 'kracare', 'may', 'god', 'humble', 'prayer'] [None, 'KPC', None, 'KRA', None, 'KRA', None, None, None, None]
#
# 298  google ['google'] ['Google']
#
# 299  i basically did electrical engineering so i wouldn't mind ['basically', 'electrical', 'engineering', 'would', "n't", 'mind'] [None, None, None, None, None, None]
#
# 300  3 ['3'] ['UN']
#
# 301  11, 13, 4 ['11', ',', '13', ',', '4'] ['Google', None, 'KCB', None, 'KRA']
#
# 302  9 ['9'] ['Unilever']
#
# 303  don't wanna work....  i want to employ.... ["n't", 'wan', 'work', '....', 'employ', '....'] [None, None, None, None, None, None]
#
# 304  @safaricomplc and  @spotify ['@', 'safaricomplc', '@', 'spotify'] [None, 'Safaricom', None, None]
#
# 305  writerbay, deskmatetutors or uvocorp ['writerbay', ',', 'deskmatetutors', 'uvocorp'] [None, None, None, None]
#
# 306 @carolmutua1 @brucenyaruri  @kengenkenya @rebecca_miano is kandie the old mzungu lady? ['@', 'carolmutua1', '@', 'brucenyaruri', '@', 'kengenkenya', '@', 'rebecca_miano', 'kandie', 'old', 'mzungu', 'lady', '?'] [None, None, None, None, None, 'KenGen', None, None, None, None, 'UN', None, None]
#
# 307  huawei ['huawei'] [None]
#
# 308  united nations ['united', 'nations'] ['UN', None]
#
# 309  the most corrupt - 5, 6, 1 at least here i'll loot 'kitu kidogo' for myself. ['corrupt', '-', '5', ',', '6', ',', '1', 'least', "'ll", 'loot', "'kitu", 'kidogo', "'", '.'] [None, None, 'KenGen', None, 'KPC', None, 'Safaricom', None, None, None, None, None, None, None]
#
# 310  @kracorporate ['@', 'kracorporate'] [None, 'KRA']
#
# 311  @kengenkenya ['@', 'kengenkenya'] [None, 'KenGen']
#
# 312  3 ['3'] ['UN']
#
# 313  kengen for sure. followed by kra alafu kplc ['kengen', 'sure', '.', 'followed', 'kra', 'alafu', 'kplc'] ['KenGen', None, None, None, 'KRA', None, 'Kplc']
#
# 314 @ki_pro_tich @itsdennohbruh @anti_saiyan  hehehe ['@', 'ki_pro_tich', '@', 'itsdennohbruh', '@', 'anti_saiyan', 'hehehe'] [None, None, None, None, None, None, None]
#
# 315  @unitednations
# @dhl
# @royalmediaservices ['@', 'unitednations', '@', 'dhl', '@', 'royalmediaservices'] [None, 'UN', None, None, None, 'RMS']
#
# 316  eabl ['eabl'] ['EABL']
#
# 317 @njoro_githiri  @kengenkenya all the best bro si kurahisi ['@', 'njoro_githiri', '@', 'kengenkenya', 'best', 'bro', 'kurahisi'] [None, None, None, 'KenGen', None, None, 'KRA']
#
# 318  3 ['3'] ['UN']
#
# 319  9 ['9'] ['Unilever']
#
# 320  i am an alumnus for the @kengen_foundatn , class of 200 it will be a dream come true to work at @kengenkenya ['alumnus', '@', 'kengen_foundatn', ',', 'class', '200', 'dream', 'true', 'work', '@', 'kengenkenya'] [None, None, 'KenGen', None, None, None, None, None, None, None, 'KenGen']
#
# 321  @deloittekenya or @ifc_org . from my mouth to god's ears. in the meantime aligning myself ['@', 'deloittekenya', '@', 'ifc_org', '.', 'mouth', 'god', "'s", 'ears', '.', 'meantime', 'aligning'] [None, 'Deloitte', None, None, None, None, None, None, None, None, None, None]
#
# 322  #14 @iamkiptoo @tindi_ @ronoray manifesting https://t.co/gciqxe5iic ['#', '14', '@', 'iamkiptoo', '@', 'tindi_', '@', 'ronoray', 'manifesting', 'https', ':', '//t.co/gciqxe5iic'] [None, 'Microsoft', None, None, None, None, None, None, None, None, None, None]
#
# 323  united nations ['united', 'nations'] ['UN', None]
#
# 324  simuweke traffic police hapo ['simuweke', 'traffic', 'police', 'hapo'] [None, None, 'Kplc', None]
#
# 325  @amref_kenya one day. ['@', 'amref_kenya', 'day', '.'] [None, 'Amref', None, None]
#
# 326  @itsjoeke un habitat ['@', 'itsjoeke', 'un', 'habitat'] [None, None, 'UN', None]
#
# 327  @kengenkenya  i would definitely welcome any opportunity to work with kengen ['@', 'kengenkenya', 'would', 'definitely', 'welcome', 'opportunity', 'work', 'kengen'] [None, 'KenGen', None, None, None, None, None, 'KenGen']
#
# 328 @alvin2_holy  uniliver sijui ni wapi mi nadai unilever😌 ['@', 'alvin2_holy', 'uniliver', 'sijui', 'wapi', 'nadai', 'unilever😌'] [None, None, 'Unilever', None, None, None, 'Unilever']
#
# 329  @amref_kenya ['@', 'amref_kenya'] [None, 'Amref']
#
# 330  united nations ['united', 'nations'] ['UN', None]
#
# 331  safaricom ['safaricom'] ['Safaricom']
#
# 332  my is not in the list.
# https://t.co/80gwu6w77g ['list', '.', 'https', ':', '//t.co/80gwu6w77g'] [None, None, None, None, None]
#
# 333  1 kemri @kemri_kenya i would wish to work with this institute. it had been helping sickle cell children. i have been a warrior of the same. that aside, i plan to do an environmental study on public sanitation for my second degree in 202 kemri will come in handy. ['1', 'kemri', '@', 'kemri_kenya', 'would', 'wish', 'work', 'institute', '.', 'helping', 'sickle', 'cell', 'children', '.', 'warrior', '.', 'aside', ',', 'plan', 'environmental', 'study', 'public', 'sanitation', 'second', 'degree', '202', 'kemri', 'handy', '.'] ['Safaricom', 'KEMRI', None, 'KEMRI', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'Kplc', None, None, None, None, 'KEMRI', None, None]
#
# 334  @rescueorg that is my dream job @ppbkenya as a drug inspector. lord hear my prayers ['@', 'rescueorg', 'dream', 'job', '@', 'ppbkenya', 'inspector', '.', 'lord', 'hear', 'prayers'] [None, None, None, None, None, None, None, None, None, None, None]
#
# 335  in order of preference
# 3
# 14
# 8
# 11
# 5 ['order', 'preference', '3', '14', '8', '11', '5'] [None, None, 'UN', 'Microsoft', 'Deloitte', 'Google', 'KenGen']
#
# 336  goggle ['goggle'] ['Google']
#
# 337  @safaricomplc  mostly ['@', 'safaricomplc', 'mostly'] [None, 'Safaricom', None]
#
# 338  1,4,5,7,11,13,14 ['1,4,5,7,11,13,14'] [None]
#
# 339  safaricom ['safaricom'] ['Safaricom']
#
# 340  none of those ['none'] [None]
#
# 341  1,2,3,8 and 1 ['1,2,3,8', '1'] [None, 'Safaricom']
#
# 342  kemri @kemri_kenya ['kemri', '@', 'kemri_kenya'] ['KEMRI', None, 'KEMRI']
#
# 343  eabl ['eabl'] ['EABL']
#
# 344  unilever or kemri or coca-cola or eabl. ['unilever', 'kemri', 'coca-cola', 'eabl', '.'] ['Unilever', 'KEMRI', 'Coca cola', 'EABL', None]
#
# 345  @kenyarailways_ ['@', 'kenyarailways_'] [None, None]
#
# 346  3 ['3'] ['UN']
#
# 347  why is @bidcogroup in this list? ['@', 'bidcogroup', 'list', '?'] [None, 'Bidco', None, None]
#
# 348  @kengenkenya ['@', 'kengenkenya'] [None, 'KenGen']
#
# 349  if there is no kemsa on that list then list is incomplete, ['kemsa', 'list', 'list', 'incomplete', ','] [None, None, None, None, None]
#
# 350  google or microsoft ['google', 'microsoft'] ['Google', 'Microsoft']
#
# 351 @carolmutua1  @kengenkenya @rebecca_miano it's my dream also that one day i will work under her able leadership and also meet wonderful people like mr. audi and the rest.
# #energychampion ['@', 'carolmutua1', '@', 'kengenkenya', '@', 'rebecca_miano', "'s", 'dream', 'day', 'work', 'able', 'leadership', 'meet', 'wonderful', 'people', 'like', 'mr.', 'audi', 'rest', '.', '#', 'energychampion'] [None, None, None, 'KenGen', None, None, None, None, None, None, 'EABL', None, None, None, None, None, None, None, None, None, None, None]
#
# 352  @safaricomplc ['@', 'safaricomplc'] [None, 'Safaricom']
#
# 353  i'd like to own shares in all of them ... then go back to my farm and smell the roses. amen ["'d", 'like', 'shares', '...', 'go', 'back', 'farm', 'smell', 'roses', '.', 'amen'] [None, None, None, None, 'Google', None, None, None, None, None, 'Amref']
#
# 354  i may not work @unitednations in 2022 but in the near future i will  work at the organization. ['may', 'work', '@', 'unitednations', '2022', 'near', 'future', 'work', 'organization', '.'] [None, None, None, 'UN', None, None, None, None, None, None]
#
# 355  @eabl_plc ['@', 'eabl_plc'] [None, 'EABL']
#
# 356  google and microsoft 🙌🏽 ['google', 'microsoft', '🙌🏽'] ['Google', 'Microsoft', None]
#
# 357  @lewanjoski @un ['@', 'lewanjoski', '@', 'un'] [None, None, None, 'UN']
#
# 358 @njoro_githiri  @kengenkenya same bana.i simped for this company wueh! ['@', 'njoro_githiri', '@', 'kengenkenya', 'bana.i', 'simped', 'company', 'wueh', '!'] [None, None, None, 'KenGen', None, None, None, None, None]
#
# 359  @kracorporate @kengenkenya ['@', 'kracorporate', '@', 'kengenkenya'] [None, 'KRA', None, 'KenGen']
#
# 360  i want  @nsis ['@', 'nsis'] [None, None]
# 361  my dream job is at @nasa ['dream', 'job', '@', 'nasa'] [None, None, None, None]
#
# 362  18 ['18'] ['Amref']
#
# 363  @amref_kenya 🙏🙏 ['@', 'amref_kenya', '🙏🙏'] [None, 'Amref', None]
#
# 364  must you think about working for someone...?
# you should be thinking about starting your own hustle ['must', 'think', 'working', 'someone', '...', '?', 'thinking', 'starting', 'hustle'] [None, None, None, None, None, None, None, None, None]
#
# 365  @nis hu apply wapi ['@', 'nis', 'hu', 'apply', 'wapi'] [None, None, None, None, None]
#
# 366 @handa_hp  😂😂😂 ['@', 'handa_hp', '😂😂😂'] [None, None, None]
#
# 367  @kracorporate all about taxes ['@', 'kracorporate', 'taxes'] [None, 'KRA', None]
#
# 368  @cocacola ['@', 'cocacola'] [None, 'Coca cola']
#
# 369  safaricom is good ['safaricom', 'good'] ['Safaricom', 'Google']
#
# 370  kenyan parliament, there is more opportunity to rob kenyans with legislation. ['kenyan', 'parliament', ',', 'opportunity', 'rob', 'kenyans', 'legislation', '.'] ['KenGen', None, None, None, None, None, None, None]
#
# 371  @cocacola ['@', 'cocacola'] [None, 'Coca cola']
#
# 372 @governorkiongos @itsdennohbruh @anti_saiyan  unasema atakuwa mlami 🤣 ['@', 'governorkiongos', '@', 'itsdennohbruh', '@', 'anti_saiyan', 'unasema', 'atakuwa', 'mlami', '🤣'] [None, None, None, None, None, None, 'UN', None, None, None]
#
# 373  kengen ['kengen'] ['KenGen']
#
# 374  @eabl_plc ['@', 'eabl_plc'] [None, 'EABL']
#
# 375  @deloitte ['@', 'deloitte'] [None, 'Deloitte']
#
# 376  continue working where i am. ['continue', 'working', '.'] [None, None, None]
#
# 377  kcb ['kcb'] ['KCB']
#
# 378  google ['google'] ['Google']
#
# 379  @eabl_plc ['@', 'eabl_plc'] [None, 'EABL']
#
# 380  according to who... employees or jobseekers? ['according', '...', 'employees', 'jobseekers', '?'] [None, None, None, None, None]
#
# 381  @kcbgroup  i would like to work with you given the opportunity since my area of speciliazation is in finance. ['@', 'kcbgroup', 'would', 'like', 'work', 'given', 'opportunity', 'since', 'area', 'speciliazation', 'finance', '.'] [None, 'KCB', None, None, None, None, None, None, 'Amref', None, None, None]
#
# 382  @kemri_kenya and @amref_kenya ['@', 'kemri_kenya', '@', 'amref_kenya'] [None, 'KEMRI', None, 'Amref']
#
# 383 @el_mechanik  dead🤡 ['@', 'el_mechanik', 'dead🤡'] [None, None, None]
#
# 384  11 ['11'] ['Google']
#
# 385  @un ['@', 'un'] [None, 'UN']
#
# 386  united nations ['united', 'nations'] ['UN', None]
#
# 387  4 ['4'] ['KRA']
#
# 388 @brucenyaruri  @kengenkenya @rebecca_miano madam kandie is a polished hr guru,i wish one day i will get a chance to work with her. ['@', 'brucenyaruri', '@', 'kengenkenya', '@', 'rebecca_miano', 'madam', 'kandie', 'polished', 'hr', 'guru', ',', 'wish', 'day', 'get', 'chance', 'work', '.'] [None, None, None, 'KenGen', None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 389  eabl ['eabl'] ['EABL']
#
# 390  @safaricomplc worked there as an intern last year (contractor - techminds technologies) and the experience was top tier. i’ve been applying for a similar position there after internship but my application has never been successful. my dream is to be a permanent employee. ['@', 'safaricomplc', 'worked', 'intern', 'last', 'year', '(', 'contractor', '-', 'techminds', 'technologies', ')', 'experience', 'top', 'tier', '.', '’', 'applying', 'similar', 'position', 'internship', 'application', 'never', 'successful', '.', 'dream', 'permanent', 'employee', '.'] [None, 'Safaricom', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'Unilever', None, None, None, None, None, None]
#
# 391  15 ['15'] ['Bidco']
#
# 392  2 ['2'] ['EABL']
#
# 393  16 ['16'] ['RMS']
#
# 394  14
# @microsoft ['14', '@', 'microsoft'] ['Microsoft', None, 'Microsoft']
#
# 395  my dream company is and will always be @kengenkenya @rebecca_miano hope my dream will come true one day. ['dream', 'company', 'always', '@', 'kengenkenya', '@', 'rebecca_miano', 'hope', 'dream', 'true', 'day', '.'] [None, None, None, None, 'KenGen', None, None, None, None, None, None, None]
#
# 396 @engmagondu1 @joenyayo  @amref_kenya 👍🏾 ['@', 'engmagondu1', '@', 'joenyayo', '@', 'amref_kenya', '👍🏾'] [None, None, None, None, None, 'Amref', None]
#
# 397 @davidjumbi  either of the following
# 2, 5 or 14 ['@', 'davidjumbi', 'either', 'following', '2', ',', '5', '14'] [None, None, None, None, 'EABL', None, 'KenGen', 'Microsoft']
#
# 398  @kenyapipeline would be a perfect destination for me ['@', 'kenyapipeline', 'would', 'perfect', 'destination'] [None, 'KPC', None, None, None]
#
# 399  ain't seeing my company 😠 ["n't", 'seeing', 'company', '😠'] [None, None, None, None]
#
# 400  @microsoft  🙏🙏 ['@', 'microsoft', '🙏🙏'] [None, 'Microsoft', None]
#
# 401  royal media services.
# inooro fm. may the lord help me ['royal', 'media', 'services', '.', 'inooro', 'fm', '.', 'may', 'lord', 'help'] ['RMS', None, None, None, None, None, None, None, None, None]
#
# ...
#
# 1474  @amref_kenya anyday and twice on sundays ['@', 'amref_kenya', 'anyday', 'twice', 'sundays'] [None, 'Amref', None, None, 'UN']
#
# 1475  666 ['666'] [None]
#
# 1476  none ['none'] [None]
#
# 1477  11,14,3,5 and 12 in that order. dear god please 🙏 ['11,14,3,5', '12', 'order', '.', 'dear', 'god', 'please', '🙏'] [None, 'KPA', None, None, None, None, None, None]
#
# 1478  royal media services
# i'm seeking an internship(journalism and mass communication) ['royal', 'media', 'services', "'m", 'seeking', 'internship', '(', 'journalism', 'mass', 'communication', ')'] ['RMS', None, None, None, None, None, None, None, None, None, None]
#
# 1479  my company to be number 19 ['company', 'number', '19'] [None, None, None]
#
# 1480  grow my company. i have no intention to grow anybody's company ['grow', 'company', '.', 'intention', 'grow', 'anybody', "'s", 'company'] [None, None, None, 'UN', None, None, None, None]
#
# 1481 @brysonmu6  4 ['@', 'brysonmu6', '4'] [None, None, 'KRA']
#
# 1482  un ['un'] ['UN']
#
# 1483  none bt imma need shares in all ['none', 'bt', 'imma', 'need', 'shares'] [None, None, None, None, None]
#
# 1484  biodigester septic tank installation services for residential 85k
# commercial 120k
# institutional 180k
# call @0714855296
# dm @jmutuabiodiges
# we offer services countrywide call us today. https://t.co/odboonbnft ['biodigester', 'septic', 'tank', 'installation', 'services', 'residential', '85k', 'commercial', '120k', 'institutional', '180k', 'call', '@', '0714855296', 'dm', '@', 'jmutuabiodiges', 'offer', 'services', 'countrywide', 'call', 'us', 'today', '.', 'https', ':', '//t.co/odboonbnft'] [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 1485  @deloittekenya, @kengenkenya ['@', 'deloittekenya', ',', '@', 'kengenkenya'] [None, 'Deloitte', None, None, 'KenGen']
#
# 1486  add us to that list ['add', 'us', 'list'] [None, None, None]
#
# 1487  manifesting collaborations with all. 😊😊😊 ['manifesting', 'collaborations', '.', '😊😊😊'] [None, None, None, None]
#
# 1488  @kcbgroup, i always dream of joining these amazing people. given a chance ['@', 'kcbgroup', ',', 'always', 'dream', 'joining', 'amazing', 'people', '.', 'given', 'chance'] [None, 'KCB', None, None, None, None, None, None, None, None, None]
#
# 1489  kpa. pesa iko huko ['kpa', '.', 'pesa', 'iko', 'huko'] ['KPA', None, None, None, None]
#
# 1490  vivo energy ['vivo', 'energy'] [None, None]
#
# 1491  been with @eabl_plc  a few years back won't mind another shot. ['@', 'eabl_plc', 'years', 'back', "n't", 'mind', 'another', 'shot', '.'] [None, 'EABL', None, None, None, None, None, None, None]
#
# 1492  @un definitely.oh god make it so. ['@', 'un', 'definitely.oh', 'god', 'make', '.'] [None, 'UN', None, None, None, None]
#
# 1493  kenya ports authority
# kenya pipeline company
#
# from my tweets to god's tl🙏 ['kenya', 'ports', 'authority', 'kenya', 'pipeline', 'company', 'tweets', 'god', "'s", 'tl🙏'] ['Kplc', None, None, 'Kplc', None, None, None, None, None, None]
#
# 1494  @kenya_ports ,,ill keep on trying,🙏🏿🙏🏿 ['@', 'kenya_ports', ',', ',ill', 'keep', 'trying', ',', '🙏🏿🙏🏿'] [None, 'KPA', None, None, 'KenGen', None, None, None]
#
# 1495 @pnalele @itsbillyricky @mstephano_  nyisa yore gi baa @pnalele ['@', 'pnalele', '@', 'itsbillyricky', '@', 'mstephano_', 'nyisa', 'yore', 'gi', 'baa', '@', 'pnalele'] [None, None, None, None, None, None, None, None, None, None, None, None]
#
# 1496  kenya ports authority ['kenya', 'ports', 'authority'] ['Kplc', None, None]
#
# 1497  3 ['3'] ['UN']
#
# 1498  @simu_digital ['@', 'simu_digital'] [None, None]
#
# 1499  they are all great... simply any of them ['great', '...', 'simply'] [None, None, None]
#
# 1500  @microsoft  @kcb  @googleafrica ['@', 'microsoft', '@', 'kcb', '@', 'googleafrica'] [None, 'Microsoft', None, 'KCB', None, 'Google']
#
# 1501  @kengenkenya ['@', 'kengenkenya'] [None, 'KenGen']
#
# 1502  2 ['2'] ['EABL']
#
# 1503  bidco ['bidco'] ['Bidco']
#
# 1504  @eabl all the time. i once worked there but covid - 19 ikaharibu kazi. given another opportunity, nitachapa kazi ['@', 'eabl', 'time', '.', 'worked', 'covid', '-', '19', 'ikaharibu', 'kazi', '.', 'given', 'another', 'opportunity', ',', 'nitachapa', 'kazi'] [None, 'EABL', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 1505 @clemo_justo  @tsc_ke tsc wanalipa mwalimu peanuts buana. ['@', 'clemo_justo', '@', 'tsc_ke', 'tsc', 'wanalipa', 'mwalimu', 'peanuts', 'buana', '.'] [None, None, None, None, None, None, None, None, None, None]
#
# 1506  i would love to work with @kengenkenya  this will be a dream come true. ['would', 'love', 'work', '@', 'kengenkenya', 'dream', 'true', '.'] [None, None, None, None, 'KenGen', None, None, None]
#
# 1507  1 ['1'] ['Safaricom']
#
# 1508  coca cola ['coca', 'cola'] ['Coca cola', None]
#
# 1509  @kengenkenya as a procument intern ['@', 'kengenkenya', 'procument', 'intern'] [None, 'KenGen', None, None]
#
# 1510  eabl all the time ['eabl', 'time'] ['EABL', None]
#
# 1511  no.3 ['no.3'] [None]
#
# 1512  @standardgrouplc
# @radiomaisha
# make my dream come true. ['@', 'standardgrouplc', '@', 'radiomaisha', 'make', 'dream', 'true', '.'] [None, None, None, None, None, None, None, None]
#
# 1513  kenya pipeline company ['kenya', 'pipeline', 'company'] ['Kplc', None, None]
#
# 1514  kenya power ['kenya', 'power'] ['Kplc', None]
#
# 1515 @pnalele @mstephano_  😂😂😂bed mos ['@', 'pnalele', '@', 'mstephano_', '😂😂😂bed', 'mos'] [None, None, None, None, None, 'Microsoft']
#
# 1516  @kenyaairways  let us fly together as your member of the cabin crew team! ['@', 'kenyaairways', 'let', 'us', 'fly', 'together', 'member', 'cabin', 'crew', 'team', '!'] [None, None, None, None, None, None, None, None, None, None, None]
#
# 1517  @kengenkenya ['@', 'kengenkenya'] [None, 'KenGen']
#
# 1518  @safaricomplc  @microsoft  @google these three are my dream jobs ['@', 'safaricomplc', '@', 'microsoft', '@', 'google', 'three', 'dream', 'jobs'] [None, 'Safaricom', None, 'Microsoft', None, 'Google', None, None, None]
#
# 1519  where is @kenyaairways ? ['@', 'kenyaairways', '?'] [None, None, None]
#
# 1520  my own... tj properties ltd😎 ['...', 'tj', 'properties', 'ltd😎'] [None, None, None, None]
#
# 1521 @cacxy  @amref_kenya you need to be atleast an emt to drive their ambulances. driving skills alone won't qualify you. ['@', 'cacxy', '@', 'amref_kenya', 'need', 'atleast', 'emt', 'drive', 'ambulances', '.', 'driving', 'skills', 'alone', "n't", 'qualify', '.'] [None, None, None, 'Amref', None, None, None, None, None, None, None, None, None, None, None, None]
#
# 1522  united nations though not so easy !! ['united', 'nations', 'though', 'easy', '!', '!'] ['UN', None, None, None, None, None]
#
# 1523  1 or 11 or 14  🤲 ['1', '11', '14', '🤲'] ['Safaricom', 'Google', 'Microsoft', None]
#
# 1524  iko wapi kanjo hapa? ['iko', 'wapi', 'kanjo', 'hapa', '?'] [None, None, None, None, None]
#
# 1525 @_b_abu_  @safaricomplc kabisa bro. ['@', '_b_abu_', '@', 'safaricomplc', 'kabisa', 'bro', '.'] [None, None, None, 'Safaricom', None, None, None]
#
# 1526  i decide to choose coca-cola ['decide', 'choose', 'coca-cola'] [None, None, 'Coca cola']
#
# 1527  kenya pipeline company ['kenya', 'pipeline', 'company'] ['Kplc', None, None]
#
# 1528  sioni rubis energy kwa list 😌 ['sioni', 'rubis', 'energy', 'kwa', 'list', '😌'] [None, None, None, 'KRA', None, None]
#
# 1529  14 microsoft ['14', 'microsoft'] ['Microsoft', 'Microsoft']
#
# 1530  kra ['kra'] ['KRA']
#
# 1531  8 ['8'] ['Deloitte']
#
# 1532  @kracorporate must be my best ['@', 'kracorporate', 'must', 'best'] [None, 'KRA', None, None]
#
# 1533  no.5 ['no.5'] [None]
#
# 1534  @dylanswaysltd best company with good working environment and condition ['@', 'dylanswaysltd', 'best', 'company', 'good', 'working', 'environment', 'condition'] [None, None, None, None, 'Google', None, None, None]
#
# 1535  hello @kracare ['hello', '@', 'kracare'] [None, None, 'KRA']
#
# 1536  deloitte ['deloitte'] ['Deloitte']
# 1537  @deloittekenya .....i just hope my wish be granted ['@', 'deloittekenya', '.....', 'hope', 'wish', 'granted'] [None, 'Deloitte', None, None, None, None]
#
# 1538  @un anytime ['@', 'un', 'anytime'] [None, 'UN', None]
#
# 1539  amref, i always admire doctor githinji gitahi ['amref', ',', 'always', 'admire', 'doctor', 'githinji', 'gitahi'] ['Amref', None, None, 'Amref', None, None, None]
#
# 1540  where is @kracare ['@', 'kracare'] [None, 'KRA']
#
# 1541  bidco ['bidco'] ['Bidco']
#
# 1542  want to be a contractor for 1,4,5,6,10 and 1 ['contractor', '1,4,5,6,10', '1'] [None, None, 'Safaricom']
#
# 1543  @kengenkenya or @kenyapower_care ['@', 'kengenkenya', '@', 'kenyapower_care'] [None, 'KenGen', None, 'Kplc']
#
# 1544  kengen ['kengen'] ['KenGen']
#
# 1545  united nations ['united', 'nations'] ['UN', None]
#
# 1546  kengen ['kengen'] ['KenGen']
#
# 1547  kemri man. kemri. ['kemri', '.', 'kemri', '.'] ['KEMRI', None, 'KEMRI', None]
#
# 1548  ekati hauliers limited ['ekati', 'hauliers', 'limited'] [None, None, None]
#
# 1549  @safaricomplc my dream ['@', 'safaricomplc', 'dream'] [None, 'Safaricom', None]
#
# 1550 @dannk_9 these guys just manage social media. they don't hire ['@', 'dannk_9', 'guys', 'manage', 'social', 'media', '.', "n't", 'hire'] [None, None, None, None, None, None, None, None, None]
#
# 1551  royal media ['royal', 'media'] ['RMS', None]
#
# 1552 @jaokojohnmark  @amref_kenya 12yrs of safe driving and 3 of those driving a staff van. i'm also licensed to carry passangers. ['@', 'jaokojohnmark', '@', 'amref_kenya', '12yrs', 'safe', 'driving', '3', 'driving', 'staff', '.', "'m", 'licensed', 'carry', 'passangers', '.'] [None, None, None, 'Amref', None, None, None, 'UN', None, None, None, None, None, None, None, None]
#
# 1553  @bennytothedj un conserving the environment ['@', 'bennytothedj', 'un', 'conserving', 'environment'] [None, None, 'UN', None, None]
#
# 1554  why.... 4 and 12 if you have connections 😅 ['....', '4', '12', 'connections', '😅'] [None, 'KRA', 'KPA', None, None]
#
# 1555  kra ['kra'] ['KRA']
#
# 1556  @kracorporate 🙏🙏🙏 ['@', 'kracorporate', '🙏🙏🙏'] [None, 'KRA', None]
#
# 1557  6 ['6'] ['KPC']
#
# 1558  kengen ['kengen'] ['KenGen']
#
# 1559   united nations @un ... always has been my dream to serve in a research related capacity in the social development sector.
# so help me god!🙏 ['united', 'nations', '@', 'un', '...', 'always', 'dream', 'serve', 'research', 'related', 'capacity', 'social', 'development', 'sector', '.', 'help', 'god', '!', '🙏'] ['UN', None, None, 'UN', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 1560  the un. ['un', '.'] ['UN', None]
#
# 1561 @clemo_justo @mwderek  @tsc_ke no way. @tsc_ke na muhindi no difference. ['@', 'clemo_justo', '@', 'mwderek', '@', 'tsc_ke', 'way', '.', '@', 'tsc_ke', 'muhindi', 'difference', '.'] [None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 1562  google ['google'] ['Google']
#
# 1563  @safaricomplc @kengenkenya ['@', 'safaricomplc', '@', 'kengenkenya'] [None, 'Safaricom', None, 'KenGen']
#
# 1564 @governorkiongos @anti_saiyan  analytical chem ['@', 'governorkiongos', '@', 'anti_saiyan', 'analytical', 'chem'] [None, None, None, None, None, None]
#
# 1565  hammjaeka @judiciary hapo perks kibao hata ukiwa mtu wa kufagia ['hammjaeka', '@', 'judiciary', 'hapo', 'perks', 'kibao', 'hata', 'ukiwa', 'mtu', 'wa', 'kufagia'] [None, None, None, None, None, None, None, None, None, None, None]
#
# 1566  2 ['2'] ['EABL']
#
# 1567 @jomusicke  thank you jo for your interest in working with us. always check opportunities on our website at https://t.co/koknbshlnk.
#
# regards.
# iosoft team. ['@', 'jomusicke', 'thank', 'interest', 'working', 'us', '.', 'always', 'check', 'opportunities', 'website', 'https', ':', '//t.co/koknbshlnk', '.', 'regards', '.', 'iosoft', 'team', '.'] [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'Microsoft', None, None]
#
# 1568  safaricom or kengen ['safaricom', 'kengen'] ['Safaricom', 'KenGen']
#
# 1569  10 ['10'] ['Kplc']
#
# 1570  i'd forever work for @iosofttech. always software &amp; technology are my bests in life. ["'d", 'forever', 'work', '@', 'iosofttech', '.', 'always', 'software', '&', 'amp', ';', 'technology', 'bests', 'life', '.'] [None, None, None, None, 'Microsoft', None, None, None, None, None, None, None, None, None, None]
#
# 1571  @apple ['@', 'apple'] [None, None]
#
# 1572  kra or kpa ['kra', 'kpa'] ['KRA', 'KPA']
#
# 1573  united nations ['united', 'nations'] ['UN', None]
#
# 1574  @un . environmental enthusiast. 😊 ['@', 'un', '.', 'environmental', 'enthusiast', '.', '😊'] [None, 'UN', None, None, None, None, None]
#
# 1575  un ['un'] ['UN']
#
# 1576  kpa ['kpa'] ['KPA']
#
# 1577  safaricom ['safaricom'] ['Safaricom']
#
# 1578  any,salary ikue tu fiti [',', 'salary', 'ikue', 'fiti'] [None, None, None, None]
#
# 1579  @kenya_ports ['@', 'kenya_ports'] [None, 'KPA']
#
# 1580  @kengenkenya @kenyapipeline ['@', 'kengenkenya', '@', 'kenyapipeline'] [None, 'KenGen', None, 'KPC']
#
# 1581  @kemri_kenya... with the required statistical skills i have, i am able to analyse and interpret statistical analysis reports by analysing and interpreting data using statistical software such as r and r, stata and spss correctly.. am ready to work with you ['@', 'kemri_kenya', '...', 'required', 'statistical', 'skills', ',', 'able', 'analyse', 'interpret', 'statistical', 'analysis', 'reports', 'analysing', 'interpreting', 'data', 'using', 'statistical', 'software', 'r', 'r', ',', 'stata', 'spss', 'correctly', '..', 'ready', 'work'] [None, 'KEMRI', None, None, None, None, None, 'EABL', None, None, None, None, None, None, None, None, None, None, None, 'RMS', 'RMS', None, None, None, None, None, None, None]
#
# 1582  @kcbgroup ['@', 'kcbgroup'] [None, 'KCB']
#
# 1583  united nations ['united', 'nations'] ['UN', None]
#
# 1584  deloitte anytime 💯 ['deloitte', 'anytime', '💯'] ['Deloitte', None, None]
#
# 1585  7 ['7'] ['Coca cola']
#
# 1586  united nations ['united', 'nations'] ['UN', None]
#
# 1587  hello @kracare ['hello', '@', 'kracare'] [None, None, 'KRA']
#
# 1588  google ['google'] ['Google']
#
# 1589  4, 5 ['4', ',', '5'] ['KRA', None, 'KenGen']
#
# 1590  4 ['4'] ['KRA']
#
# 1591  safaricom ['safaricom'] ['Safaricom']
#
# 1592  eabl. ['eabl', '.'] ['EABL', None]
#
# 1593  united nations ['united', 'nations'] ['UN', None]
#
# 1594  united nations ['united', 'nations'] ['UN', None]
#
# 1595  none. maybe work with ['none', '.', 'maybe', 'work'] [None, None, None, None]
#
# 1596  self employment to the moon ['self', 'employment', 'moon'] [None, None, None]
#
# 1597  5 &amp; 7 ['5', '&', 'amp', ';', '7'] ['KenGen', None, None, None, 'Coca cola']
#
# 1598  12, why? ['12', ',', '?'] ['KPA', None, None]
#
# 1599  3 ['3'] ['UN']
#
# 1600  1 4 7 ['1', '4', '7'] ['Safaricom', 'KRA', 'Coca cola']
#
# 1601  deloitte ['deloitte'] ['Deloitte']
#
# 1602  3 ['3'] ['UN']
#
# 1603  amref 🙏🏾 ['amref', '🙏🏾'] ['Amref', None]
#
# 1604  hapana hakuna kubagua..... mboka ni mboka..... ikijipa, jitume... 💪😎💥💯..... all of them.... 😂😂😂😂 ['hapana', 'hakuna', 'kubagua', '.....', 'mboka', 'mboka', '.....', 'ikijipa', ',', 'jitume', '...', '💪😎💥💯', '.....', '....', '😂😂😂😂'] [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# 1605  ukipewa gig pia peana🤣🤣🤣 ['ukipewa', 'gig', 'pia', 'peana🤣🤣🤣'] [None, None, None, None]
#
# 1606  12 kenya ports authority ['12', 'kenya', 'ports', 'authority'] ['KPA', 'Kplc', None, None]
#
# 1607  4 ['4'] ['KRA']
#
# 1608  kenya pipeline company ['kenya', 'pipeline', 'company'] ['Kplc', None, None]
#
# 1609  1 or 9 or 11 or 14 ['1', '9', '11', '14'] ['Safaricom', 'Unilever', 'Google', 'Microsoft']
#
# 1610  @kcbgroup i owe them alot😁💪🏾 ['@', 'kcbgroup', 'owe', 'alot😁💪🏾'] [None, 'KCB', None, None]
#
# 1611  my own fuckin self ['fuckin', 'self'] [None, None]
#
# 1612  3,6 or 12 ['3,6', '12'] [None, 'KPA']
#
# 1613  this looks like some max verstappen shit! ['looks', 'like', 'max', 'verstappen', 'shit', '!'] [None, None, None, None, None, None]

# %%
# tt= narr[908]
# nt = replaceEmoji(tt)
# print(nt)

# word_tokenize(nt)
# # narr[908]

# output_arr

# %%
finalarr = [txt.lower() for txt in output_arr if txt is not None]

# finalarr

# %%
corpus = "; ".join(finalarr)
# corpus

# %%
cols = ['Companies']
df_out = pd.DataFrame(finalarr, columns = cols )
df_grp = df_out.groupby(cols).size().reset_index(name='Count')

# %%
df_grp.sort_values(by='Count', ascending=False)
# Out:
#     Companies  Count
# 16         un    263
# 5      google    164
# 15  safaricom    145
# 8      kengen    144
# 4        eabl    122
# 0       amref    119
# 12        kra    115
# 11       kplc     96
# 13  microsoft     93
# 3    deloitte     63
# 17   unilever     60
# 2   coca cola     57
# 9         kpa     47
# 1       bidco     43
# 10        kpc     40
# 6         kcb     38
# 7       kemri     33
# 14        rms     24

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from collections import Counter
import matplotlib.pyplot as plt

word_could_dict=Counter(finalarr)

wordcloud = WordCloud(background_color="white").generate_from_frequencies(word_could_dict) #.generate(corpus) #.generate_from_frequencies(word_could_dict)    
#Post processing
#ii. plot word cloud model
plt.figure(figsize = (22,22))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# #### Notes
# Its important to note changes to metrics the last 3 days - Amref moved from 2nd to 3rd etc
#
# **Note** these interpretations are time-bound and decay over time hence it's important to keep updating this data

# %% [markdown]
# Save to csv

# %%
df_grp.sort_values(by='Count', ascending=False).to_csv('./out/sortedout.csv')
